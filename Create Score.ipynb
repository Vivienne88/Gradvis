# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv("uni3.csv")

# %%
#columns = df.columns[6:8].append(df.columns[9:])
columns = ['Tuition($)']

# %%
df[columns[0]]
# Out:
# 0     53450
# 1     55905
# 2     26544
# 3     48500
# 4     35458
# 5     29140
# 6     51126
# 7     53770
# 8     54570
# 9     29500
# 10    19320
# 11    29132
# 12    32439
# 13    50496
# 14    26544
# 15     1625
# 16    24054
# 17     2075
# 18    27614
# 19    55680
# 20    54880
# 21    40716
# 22    56067
# 23    35144
# 24    39216
# 25    48330
# 26     2267
# 27    55850
# 28      779
# 29    31400
# 30    26421
# 31    34128
# 32    27335
# 33    28330
# 34    43300
# 35     1616
# 36    28700
# 37    26544
# 38    54250
# 39     1869
# 40    30144
# 41    54720
# 42    27892
# 43    32065
# 44     8321
# 45    54000
# 46    32392
# 47    54908
# 48    23100
# 49    45808
# Name: Tuition($), dtype: int64

# %%
keys = [15, 17, 26, 28, 35, 39, 44]
for k in keys:
    df[columns[0]][k] = df[columns[0]][k] * 10
# Out:
# C:\Users\vivi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df[columns[0]]
# Out:
# 0     53450
# 1     55905
# 2     26544
# 3     48500
# 4     35458
# 5     29140
# 6     51126
# 7     53770
# 8     54570
# 9     29500
# 10    19320
# 11    29132
# 12    32439
# 13    50496
# 14    26544
# 15    16250
# 16    24054
# 17    20750
# 18    27614
# 19    55680
# 20    54880
# 21    40716
# 22    56067
# 23    35144
# 24    39216
# 25    48330
# 26    22670
# 27    55850
# 28     7790
# 29    31400
# 30    26421
# 31    34128
# 32    27335
# 33    28330
# 34    43300
# 35    16160
# 36    28700
# 37    26544
# 38    54250
# 39    18690
# 40    30144
# 41    54720
# 42    27892
# 43    32065
# 44    83210
# 45    54000
# 46    32392
# 47    54908
# 48    23100
# 49    45808
# Name: Tuition($), dtype: int64

# %%
#princeton
df[columns[0]][7] = 53770
# Out:
# C:\Users\vivi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#caltech
df[columns[0]][8] = 54570
# Out:
# C:\Users\vivi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#str_columns = df.columns[5:7]
#df[str_columns] = df[str_columns].apply(lambda x : x.str.replace(',', ''))

# %%
#percent_columns = df.columns[9:10].append(df.columns[11:12])
#df[percent_columns] = df[percent_columns].apply(lambda x : x.str.replace('%', ''))

# %%
df[columns]
# Out:
#     Tuition($)
# 0        53450
# 1        55905
# 2        26544
# 3        48500
# 4        35458
# 5        29140
# 6        51126
# 7        53770
# 8        54570
# 9        29500
# 10       19320
# 11       29132
# 12       32439
# 13       50496
# 14       26544
# 15       16250
# 16       24054
# 17       20750
# 18       27614
# 19       55680
# 20       54880
# 21       40716
# 22       56067
# 23       35144
# 24       39216
# 25       48330
# 26       22670
# 27       55850
# 28        7790
# 29       31400
# 30       26421
# 31       34128
# 32       27335
# 33       28330
# 34       43300
# 35       16160
# 36       28700
# 37       26544
# 38       54250
# 39       18690
# 40       30144
# 41       54720
# 42       27892
# 43       32065
# 44       83210
# 45       54000
# 46       32392
# 47       54908
# 48       23100
# 49       45808

# %%
score_columns = columns.map(lambda x : x + " Score")
print(score_columns)
# Out:
# Index(['Students Score', 'Tuition($) Score', 'Student/Faculty Ratio Score',
#        'Master Acceptance Score', 'Master Applicants Score',
#        'Phd Acceptance Score', 'Phd Applicants Score'],
#       dtype='object')

# %%
df[]

# %%
data = df[columns]
scaler = MinMaxScaler(feature_range=(0, 100))
scaler.fit(data)
MinMaxScaler()
new_data = scaler.transform(data)
print(new_data)
# Out:
# [[ 60.54097056]
#  [ 63.79607531]
#  [ 24.86608327]
#  [ 53.97772474]
#  [ 36.68522938]
#  [ 28.30814108]
#  [ 57.4595598 ]
#  [ 60.9652612 ]
#  [ 62.0259878 ]
#  [ 28.78546805]
#  [ 15.28772209]
#  [ 28.29753381]
#  [ 32.68231238]
#  [ 56.6242376 ]
#  [ 24.86608327]
#  [ 11.21718377]
#  [ 21.56457173]
#  [ 17.18377088]
#  [ 26.28480509]
#  [ 63.49774596]
#  [ 62.43701936]
#  [ 43.65685495]
#  [ 64.01087245]
#  [ 36.26889419]
#  [ 41.66799257]
#  [ 53.75232034]
#  [ 19.72951472]
#  [ 63.72315036]
#  [  0.        ]
#  [ 31.30469372]
#  [ 24.70299655]
#  [ 34.92177141]
#  [ 25.91487669]
#  [ 27.2341554 ]
#  [ 47.08300186]
#  [ 11.09785203]
#  [ 27.72474145]
#  [ 24.86608327]
#  [ 61.60169716]
#  [ 14.45239989]
#  [ 29.63935296]
#  [ 62.22487404]
#  [ 26.65340758]
#  [ 32.1864227 ]
#  [100.        ]
#  [ 61.2702201 ]
#  [ 32.6199947 ]
#  [ 62.47414479]
#  [ 20.29965526]
#  [ 50.40837974]]

# %%
data = df[columns]
scaler = MinMaxScaler(feature_range=(0, 100))
scaler.fit(data)
MinMaxScaler()
new_data = scaler.transform(data)
print(new_data)
# Out:
# [[ 47.4420191   95.3323702   68.          36.07142857  11.39439723
#     4.24107143 100.        ]
#  [ 52.79672578  99.71105998 100.          21.60714286  40.04406673
#     5.80357143  53.59595698]
#  [ 33.91882674  47.34335705  68.          49.82142857  33.70475291
#     7.58928571  71.98393158]
#  [ 64.18826739  86.50364742  54.          33.03571429 100.
#    14.0625      73.86290009]
#  [ 57.77626194  63.24219238  48.          48.03571429  52.42681775
#    38.39285714  54.55487884]
#  [ 66.57571623  51.97353167  46.          41.96428571  48.55524079
#    45.08928571  47.35000648]
#  [ 49.4372442   91.18732945  50.          60.          39.62228517
#    22.76785714  53.40158093]
#  [  5.66166439   0.          44.           0.           4.79697828
#    18.30357143  25.46326293]
#  [  3.20600273   0.          60.          13.57142857   0.8687441
#     2.67857143  33.4715563 ]
#  [ 34.82264666  52.6156206   56.          58.57142857  40.04406673
#    18.97321429  48.9050149 ]
# ...

# %%
for i, col in enumerate(score_columns):
    df[col] = new_data[:,i]

# %%
df["Tuition($) Score"]
# Out:
# 0      95.332370
# 1      99.711060
# 2      47.343357
# 3      86.503647
# 4      63.242192
# 5      51.973532
# 6      91.187329
# 7       0.000000
# 8       0.000000
# 9      52.615621
# 10     34.458773
# 11     51.959263
# 12     57.857563
# 13     90.063674
# 14     47.343357
# 15      2.898318
# 16     42.902242
# 17      3.700929
# 18     49.251788
# 19     99.309754
# 20     97.882890
# 21     72.620258
# 22    100.000000
# 23     62.682148
# 24     69.944887
# 25     86.200439
# 26      4.043377
# 27     99.612963
# 28      1.389409
# 29     56.004423
# 30     47.123977
# 31     60.870031
# 32     48.754169
# 33     50.528832
# 34     77.229030
# 35      2.882266
# 36     51.188756
# 37     47.343357
# 38     96.759234
# 39      3.333512
# 40     53.764246
# 41     97.597517
# 42     49.747623
# 43     57.190504
# 44     14.841172
# 45     96.313339
# 46     57.773735
# 47     97.932830
# 48     41.200706
# 49     81.702249
# Name: Tuition($) Score, dtype: float64

# %%
df["Tuition($) Score"] = new_data

# %%
df["Tuition($) Score"]
# Out:
# 0      60.540971
# 1      63.796075
# 2      24.866083
# 3      53.977725
# 4      36.685229
# 5      28.308141
# 6      57.459560
# 7      60.965261
# 8      62.025988
# 9      28.785468
# 10     15.287722
# 11     28.297534
# 12     32.682312
# 13     56.624238
# 14     24.866083
# 15     11.217184
# 16     21.564572
# 17     17.183771
# 18     26.284805
# 19     63.497746
# 20     62.437019
# 21     43.656855
# 22     64.010872
# 23     36.268894
# 24     41.667993
# 25     53.752320
# 26     19.729515
# 27     63.723150
# 28      0.000000
# 29     31.304694
# 30     24.702997
# 31     34.921771
# 32     25.914877
# 33     27.234155
# 34     47.083002
# 35     11.097852
# 36     27.724741
# 37     24.866083
# 38     61.601697
# 39     14.452400
# 40     29.639353
# 41     62.224874
# 42     26.653408
# 43     32.186423
# 44    100.000000
# 45     61.270220
# 46     32.619995
# 47     62.474145
# 48     20.299655
# 49     50.408380
# Name: Tuition($) Score, dtype: float64

# %%
print(df)
# Out:
#                                                  Name  Rank  GPA  TOEFL  \
# 0               Massachusetts Institute of Technology     1  0.0    100
# 1                                 Stanford University     2  3.6    100
# 2                  University of California--Berkeley     3  3.0     90
# 3                          Carnegie Mellon University     4  0.0    100
# 4            University of Illinois--Urbana-Champaign     5  3.0    103
# 5                     Georgia Institute of Technology     6  3.5     90
# 6                   University of Michigan--Ann Arbor     7  0.0    100
# 7                                Princeton University     8  3.6      0
# 8                  California Institute of Technology     9  0.0      0
# 9                                  Cornell University    10  3.5     77
# 10             University of Texas--Austin (Cockrell)    11  3.0     79
# 11                  Purdue University--West Lafayette    12  0.0    100
# ...

# %%
df.to_csv("uni3.csv", index=False)

# %%
df[['Students Score', 'Tuition($) Score', 'Score']]
# Out:
#     Students Score  Tuition($) Score  Score
# 0        47.442019         95.332370    100
# 1        52.796726         99.711060     88
# 2        33.918827         47.343357     82
# 3        64.188267         86.503647     76
# 4        57.776262         63.242192     69
# 5        66.575716         51.973532     73
# 6        49.437244         91.187329     76
# 7         5.661664          0.000000     57
# 8         3.206003          0.000000     76
# 9        34.822647         52.615621     67
# 10       29.467940         34.458773     69
# 11       52.523874         51.959263     75
# 12       24.539563         57.857563     54
# 13       36.425648         90.063674     67
# 14       47.629604         47.343357     71
# 15       21.418827          2.898318     58
# 16       17.479536         42.902242     54
# 17       70.992497          3.700929     69
# 18       26.142565         49.251788     52
# 19       17.428377         99.309754     55
# ...
